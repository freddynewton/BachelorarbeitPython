# %% [markdown]
# <a href="https://colab.research.google.com/github/freddynewton/BachelorarbeitPython/blob/main/Influence_Visualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python program to read
# json file
  
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Opening JSON file
f = open('/content/drive/MyDrive/JSONS/IterationManager1000_27.06.2021_12_37_41.json',)
iterationCount = 1000
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
df = pd.DataFrame(data['MatchDatas'])

# Get Pie Chart from Winner
# Get Winner Counts

fig, ax = plt.subplots()


pie_chart_exploded = (0, 0.05)
pie_chart_names = ["Shared", "Unshared"]
piePlot = df['winner'].value_counts().plot(kind='pie', fontsize=15, labels=pie_chart_names, y='', explode=pie_chart_exploded ,shadow = True, startangle=90, figsize=(15,10), autopct='%1.1f%%',  pctdistance=0.3, ax=ax)
ax.set_title("1000 iterations Ratio of games won", fontsize=20)
plt.ylabel('')

ax.legend(pie_chart_names, loc=4)

# %%
# close file
f.close()
